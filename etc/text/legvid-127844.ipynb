# %%
from pathlib import Path
import json

# %%
asr_data = json.load(Path("李昆澤-127844.gasr.json").open(encoding="UTF-8"))
metadata = json.load(Path("metadata.json").open(encoding="UTF-8"))

# %%
asr = asr_data["response"]["results"]
transcript = [x for x in metadata if x["video_id"]=="127844"][0]["transcript"]

# %% [markdown]
# ## 議事錄逐字稿

# %%
import re
from itertools import tee
def preprocess_transcript(txt):
    txt = txt.replace("<br />", "")
    txt = re.split("(\n?.+?：)", txt)    
    txt = [x.replace("\n", "").strip() for x in txt]
    txt = [x for x in txt if x]
    iter_list = [iter(txt)] * 2
    turns = [(a,b) for a,b in zip(*iter_list)]
    return turns

# %%
turns = preprocess_transcript(transcript)
turns[:5]
# Out:
# [('李委員昆澤：',
#   '（10 時 13 分）部長，您好。遊艇證照弊案傷害政府的威信，也影響到考照的公平性，更是衝擊到航運的安全，這一次的事件整體來看，內部監理出了重大漏洞，這個部分請部長簡單說明一下。'),
#  ('主席：', '請交通部林部長說明。'),
#  ('林部長佳龍：',
#   '不管原因是什麼，我們要阻止類似的事情再發生，所以我在第一時間得知檢調在偵辦，就要求同仁同步清查並全面提供資料，而且要澈底建立防弊的措施，不管是相關的作業程序或者承辦人的職權，整個檢討跟改進。'),
#  ('李委員昆澤：',
#   '航港局的檢討報告提到，要限縮相關人員的權限，加強勾稽比對，並由科長來核對、覆核，系統要更新，限制成績須整批匯入，發照人員也要定期輪調。我也具體的建議，我們必須要加強內部稽核和不定期查核，請簡單說明。'),
#  ('主席：', '請交通部航港局葉局長說明。')]

# %% [markdown]
# ## ASR

# %%
from itertools import chain

def to_num(x):
    return float(x.replace("s", ""))

def flatten_asr(asr_obj):    
    asr_starts = []
    asr_ends = []
    asr_words = []
    for entry_x in asr_obj:
        alts = entry_x.get("alternatives", [])
        if not alts: continue
        words = alts[0].get("words", [])        
        asr_starts.extend([
            to_num(x["startTime"]) for x in words])
        asr_ends.extend([
            to_num(x["endTime"]) for x in words])
        asr_words.extend([x["word"] for x in words])
        
    return {
        "starts": asr_starts,
        "ends": asr_ends,
        "words": asr_words
    }

flat_asr = flatten_asr(asr)
assert len(flat_asr["starts"]) == len(flat_asr["words"])

# %%
asr[1]
# Out:
# {'alternatives': [{'confidence': 0.923182,
#    'transcript': ' 不長你好，遊艇證照B按他傷害政府的微信也影響到口罩的公平性更是從啟導航運的安全，那這一次的事件整體來看內部的間裡啊，除了重大的漏洞，這個部分來請部長簡單說明一下，我不管他的原因是什麼，然後我們要阻止這個類似的事情再發生，那所以我在第一時間而得知檢調偵辦的時候，我就要求同仁同步的去青茶，然後全面提供資料，而且要把這一個房地的措施把他徹底建立，我不管是說這一些付把相關的這個作業程序法會的是承辦人的職權保證，各做一個檢討更改進這個。',
#    'words': [{'endTime': '15.800s', 'startTime': '15.400s', 'word': '不'},
#     {'endTime': '15.900s', 'startTime': '15.800s', 'word': '長'},
#     {'endTime': '16s', 'startTime': '15.900s', 'word': '你'},
#     {'endTime': '16.200s', 'startTime': '16s', 'word': '好'},
#     {'endTime': '17.500s', 'startTime': '16.200s', 'word': '遊'},
#     {'endTime': '17.700s', 'startTime': '17.500s', 'word': '艇'},
#     {'endTime': '18s', 'startTime': '17.700s', 'word': '證'},
#     {'endTime': '18.100s', 'startTime': '18s', 'word': '照'},
#     {'endTime': '18.300s', 'startTime': '18.100s', 'word': 'b'},
#     {'endTime': '18.600s', 'startTime': '18.300s', 'word': '按'},
#     {'endTime': '19.200s', 'startTime': '18.600s', 'word': '他'},
#     {'endTime': '20.400s', 'startTime': '19.200s', 'word': '傷'},
#     {'endTime': '20.500s', 'startTime': '20.400s', 'word': '害'},
#     {'endTime': '20.900s', 'startTime': '20.500s', 'word': '政'},
#     {'endTime': '21.100s', 'startTime': '20.900s', 'word': '府'},
#     {'endTime': '21.300s', 'startTime': '21.100s', 'word': '的'},
#     {'endTime': '21.400s', 'startTime': '21.300s', 'word': '微'},
#     {'endTime': '21.800s', 'startTime': '21.400s', 'word': '信'},
#     {'endTime': '22.500s', 'startTime': '21.800s', 'word': '也'},
#     {'endTime': '23.300s', 'startTime': '22.500s', 'word': '影'},
#     {'endTime': '23.400s', 'startTime': '23.300s', 'word': '響'},
#     {'endTime': '23.700s', 'startTime': '23.400s', 'word': '到'},
#     {'endTime': '24.400s', 'startTime': '23.700s', 'word': '口'},
#     {'endTime': '24.800s', 'startTime': '24.400s', 'word': '罩'},
#     {'endTime': '25.100s', 'startTime': '24.800s', 'word': '的'},
#     {'endTime': '25.800s', 'startTime': '25.100s', 'word': '公'},
#     {'endTime': '25.900s', 'startTime': '25.800s', 'word': '平'},
#     {'endTime': '26.100s', 'startTime': '25.900s', 'word': '性'},
#     {'endTime': '27s', 'startTime': '26.100s', 'word': '更'},
#     {'endTime': '27.100s', 'startTime': '27s', 'word': '是'},
#     {'endTime': '27.400s', 'startTime': '27.100s', 'word': '從'},
#     {'endTime': '27.600s', 'startTime': '27.400s', 'word': '啟'},
#     {'endTime': '27.800s', 'startTime': '27.600s', 'word': '導'},
#     {'endTime': '28s', 'startTime': '27.800s', 'word': '航'},
#     {'endTime': '28.900s', 'startTime': '28s', 'word': '運'},
#     {'endTime': '29s', 'startTime': '28.900s', 'word': '的'},
#     {'endTime': '29.100s', 'startTime': '29s', 'word': '安'},
#     {'endTime': '29.500s', 'startTime': '29.100s', 'word': '全'},
#     {'endTime': '30.300s', 'startTime': '29.500s', 'word': '那'},
#     {'endTime': '30.500s', 'startTime': '30.300s', 'word': '這'},
#     {'endTime': '30.500s', 'startTime': '30.500s', 'word': '一'},
#     {'endTime': '30.600s', 'startTime': '30.500s', 'word': '次'},
#     {'endTime': '30.800s', 'startTime': '30.600s', 'word': '的'},
#     {'endTime': '31s', 'startTime': '30.800s', 'word': '事'},
#     {'endTime': '31.200s', 'startTime': '31s', 'word': '件'},
#     {'endTime': '31.600s', 'startTime': '31.200s', 'word': '整'},
#     {'endTime': '31.700s', 'startTime': '31.600s', 'word': '體'},
#     {'endTime': '31.800s', 'startTime': '31.700s', 'word': '來'},
#     {'endTime': '32s', 'startTime': '31.800s', 'word': '看'},
#     {'endTime': '32.800s', 'startTime': '32s', 'word': '內'},
#     {'endTime': '33s', 'startTime': '32.800s', 'word': '部'},
#     {'endTime': '33.400s', 'startTime': '33s', 'word': '的'},
#     {'endTime': '33.900s', 'startTime': '33.400s', 'word': '間'},
#     {'endTime': '34s', 'startTime': '33.900s', 'word': '裡'},
#     {'endTime': '34.100s', 'startTime': '34s', 'word': '啊'},
#     {'endTime': '34.800s', 'startTime': '34.100s', 'word': '除'},
#     {'endTime': '35s', 'startTime': '34.800s', 'word': '了'},
#     {'endTime': '35.300s', 'startTime': '35s', 'word': '重'},
#     {'endTime': '35.600s', 'startTime': '35.300s', 'word': '大'},
#     {'endTime': '35.800s', 'startTime': '35.600s', 'word': '的'},
#     {'endTime': '35.900s', 'startTime': '35.800s', 'word': '漏'},
#     {'endTime': '36.200s', 'startTime': '35.900s', 'word': '洞'},
#     {'endTime': '37.300s', 'startTime': '36.200s', 'word': '這'},
#     {'endTime': '37.400s', 'startTime': '37.300s', 'word': '個'},
#     {'endTime': '37.500s', 'startTime': '37.400s', 'word': '部'},
#     {'endTime': '37.700s', 'startTime': '37.500s', 'word': '分'},
#     {'endTime': '38.300s', 'startTime': '37.700s', 'word': '來'},
#     {'endTime': '38.600s', 'startTime': '38.300s', 'word': '請'},
#     {'endTime': '38.700s', 'startTime': '38.600s', 'word': '部'},
#     {'endTime': '38.800s', 'startTime': '38.700s', 'word': '長'},
#     {'endTime': '39.100s', 'startTime': '38.800s', 'word': '簡'},
#     {'endTime': '39.300s', 'startTime': '39.100s', 'word': '單'},
#     {'endTime': '39.500s', 'startTime': '39.300s', 'word': '說'},
#     {'endTime': '39.600s', 'startTime': '39.500s', 'word': '明'},
#     {'endTime': '39.700s', 'startTime': '39.600s', 'word': '一'},
#     {'endTime': '39.900s', 'startTime': '39.700s', 'word': '下'},
#     {'endTime': '39.900s', 'startTime': '39.900s', 'word': '我'},
#     {'endTime': '42.100s', 'startTime': '39.900s', 'word': '不'},
#     {'endTime': '42.200s', 'startTime': '42.100s', 'word': '管'},
#     {'endTime': '42.500s', 'startTime': '42.200s', 'word': '他'},
#     {'endTime': '42.800s', 'startTime': '42.500s', 'word': '的'},
#     {'endTime': '43.400s', 'startTime': '42.800s', 'word': '原'},
#     {'endTime': '43.400s', 'startTime': '43.400s', 'word': '因'},
#     {'endTime': '43.700s', 'startTime': '43.400s', 'word': '是'},
#     {'endTime': '43.800s', 'startTime': '43.700s', 'word': '什'},
#     {'endTime': '44s', 'startTime': '43.800s', 'word': '麼'},
#     {'endTime': '44.100s', 'startTime': '44s', 'word': '然'},
#     {'endTime': '44.100s', 'startTime': '44.100s', 'word': '後'},
#     {'endTime': '44.300s', 'startTime': '44.100s', 'word': '我'},
#     {'endTime': '44.400s', 'startTime': '44.300s', 'word': '們'},
#     {'endTime': '44.600s', 'startTime': '44.400s', 'word': '要'},
#     {'endTime': '44.700s', 'startTime': '44.600s', 'word': '阻'},
#     {'endTime': '44.900s', 'startTime': '44.700s', 'word': '止'},
#     {'endTime': '45.100s', 'startTime': '44.900s', 'word': '這'},
#     {'endTime': '45.200s', 'startTime': '45.100s', 'word': '個'},
#     {'endTime': '46.500s', 'startTime': '45.200s', 'word': '類'},
#     {'endTime': '46.600s', 'startTime': '46.500s', 'word': '似'},
#     {'endTime': '46.800s', 'startTime': '46.600s', 'word': '的'},
#     {'endTime': '46.900s', 'startTime': '46.800s', 'word': '事'},
#     {'endTime': '47.100s', 'startTime': '46.900s', 'word': '情'},
#     {'endTime': '47.200s', 'startTime': '47.100s', 'word': '再'},
#     {'endTime': '47.400s', 'startTime': '47.200s', 'word': '發'},
#     {'endTime': '47.700s', 'startTime': '47.400s', 'word': '生'},
#     {'endTime': '48.700s', 'startTime': '47.700s', 'word': '那'},
#     {'endTime': '48.800s', 'startTime': '48.700s', 'word': '所'},
#     {'endTime': '48.900s', 'startTime': '48.800s', 'word': '以'},
#     {'endTime': '49s', 'startTime': '48.900s', 'word': '我'},
#     {'endTime': '49.200s', 'startTime': '49s', 'word': '在'},
#     {'endTime': '49.500s', 'startTime': '49.200s', 'word': '第'},
#     {'endTime': '49.500s', 'startTime': '49.500s', 'word': '一'},
#     {'endTime': '49.700s', 'startTime': '49.500s', 'word': '時'},
#     {'endTime': '49.900s', 'startTime': '49.700s', 'word': '間'},
#     {'endTime': '50.300s', 'startTime': '49.900s', 'word': '而'},
#     {'endTime': '50.400s', 'startTime': '50.300s', 'word': '得'},
#     {'endTime': '50.600s', 'startTime': '50.400s', 'word': '知'},
#     {'endTime': '51.200s', 'startTime': '50.600s', 'word': '檢'},
#     {'endTime': '51.300s', 'startTime': '51.200s', 'word': '調'},
#     {'endTime': '52.400s', 'startTime': '51.300s', 'word': '偵'},
#     {'endTime': '52.900s', 'startTime': '52.400s', 'word': '辦'},
#     {'endTime': '53.100s', 'startTime': '52.900s', 'word': '的'},
#     {'endTime': '53.200s', 'startTime': '53.100s', 'word': '時'},
#     {'endTime': '53.400s', 'startTime': '53.200s', 'word': '候'},
#     {'endTime': '53.500s', 'startTime': '53.400s', 'word': '我'},
#     {'endTime': '53.700s', 'startTime': '53.500s', 'word': '就'},
#     {'endTime': '53.800s', 'startTime': '53.700s', 'word': '要'},
#     {'endTime': '54s', 'startTime': '53.800s', 'word': '求'},
#     {'endTime': '54.200s', 'startTime': '54s', 'word': '同'},
#     {'endTime': '54.400s', 'startTime': '54.200s', 'word': '仁'},
#     {'endTime': '55.200s', 'startTime': '54.400s', 'word': '同'},
#     {'endTime': '55.500s', 'startTime': '55.200s', 'word': '步'},
#     {'endTime': '55.600s', 'startTime': '55.500s', 'word': '的'},
#     {'endTime': '55.900s', 'startTime': '55.600s', 'word': '去'},
#     {'endTime': '56.200s', 'startTime': '55.900s', 'word': '青'},
#     {'endTime': '56.300s', 'startTime': '56.200s', 'word': '茶'},
#     {'endTime': '56.700s', 'startTime': '56.300s', 'word': '然'},
#     {'endTime': '56.700s', 'startTime': '56.700s', 'word': '後'},
#     {'endTime': '57s', 'startTime': '56.700s', 'word': '全'},
#     {'endTime': '57.400s', 'startTime': '57s', 'word': '面'},
#     {'endTime': '57.700s', 'startTime': '57.400s', 'word': '提'},
#     {'endTime': '57.800s', 'startTime': '57.700s', 'word': '供'},
#     {'endTime': '58.100s', 'startTime': '57.800s', 'word': '資'},
#     {'endTime': '58.200s', 'startTime': '58.100s', 'word': '料'},
#     {'endTime': '58.800s', 'startTime': '58.200s', 'word': '而'},
#     {'endTime': '59.100s', 'startTime': '58.800s', 'word': '且'},
#     {'endTime': '59.300s', 'startTime': '59.100s', 'word': '要'},
#     {'endTime': '59.500s', 'startTime': '59.300s', 'word': '把'},
#     {'endTime': '59.700s', 'startTime': '59.500s', 'word': '這'},
#     {'endTime': '59.700s', 'startTime': '59.700s', 'word': '一'},
#     {'endTime': '59.900s', 'startTime': '59.700s', 'word': '個'},
#     {'endTime': '60.100s', 'startTime': '59.900s', 'word': '房'},
#     {'endTime': '60.200s', 'startTime': '60.100s', 'word': '地'},
#     {'endTime': '60.500s', 'startTime': '60.200s', 'word': '的'},
#     {'endTime': '61.500s', 'startTime': '60.500s', 'word': '措'},
#     {'endTime': '61.700s', 'startTime': '61.500s', 'word': '施'},
#     {'endTime': '62s', 'startTime': '61.700s', 'word': '把'},
#     {'endTime': '62.100s', 'startTime': '62s', 'word': '他'},
#     {'endTime': '62.500s', 'startTime': '62.100s', 'word': '徹'},
#     {'endTime': '62.600s', 'startTime': '62.500s', 'word': '底'},
#     {'endTime': '63s', 'startTime': '62.600s', 'word': '建'},
#     {'endTime': '63.100s', 'startTime': '63s', 'word': '立'},
#     {'endTime': '63.200s', 'startTime': '63.100s', 'word': '我'},
#     {'endTime': '63.500s', 'startTime': '63.200s', 'word': '不'},
#     {'endTime': '63.700s', 'startTime': '63.500s', 'word': '管'},
#     {'endTime': '63.800s', 'startTime': '63.700s', 'word': '是'},
#     {'endTime': '64s', 'startTime': '63.800s', 'word': '說'},
#     {'endTime': '65.100s', 'startTime': '64s', 'word': '這'},
#     {'endTime': '65.100s', 'startTime': '65.100s', 'word': '一'},
#     {'endTime': '65.400s', 'startTime': '65.100s', 'word': '些'},
#     {'endTime': '65.500s', 'startTime': '65.400s', 'word': '付'},
#     {'endTime': '65.800s', 'startTime': '65.500s', 'word': '把'},
#     {'endTime': '66.100s', 'startTime': '65.800s', 'word': '相'},
#     {'endTime': '66.200s', 'startTime': '66.100s', 'word': '關'},
#     {'endTime': '66.500s', 'startTime': '66.200s', 'word': '的'},
#     {'endTime': '67.300s', 'startTime': '66.500s', 'word': '這'},
#     {'endTime': '67.500s', 'startTime': '67.300s', 'word': '個'},
#     {'endTime': '67.700s', 'startTime': '67.500s', 'word': '作'},
#     {'endTime': '67.900s', 'startTime': '67.700s', 'word': '業'},
#     {'endTime': '68.100s', 'startTime': '67.900s', 'word': '程'},
#     {'endTime': '68.200s', 'startTime': '68.100s', 'word': '序'},
#     {'endTime': '68.800s', 'startTime': '68.200s', 'word': '法'},
#     {'endTime': '69.100s', 'startTime': '68.800s', 'word': '會'},
#     {'endTime': '69.200s', 'startTime': '69.100s', 'word': '的'},
#     {'endTime': '69.300s', 'startTime': '69.200s', 'word': '是'},
#     {'endTime': '69.500s', 'startTime': '69.300s', 'word': '承'},
#     {'endTime': '69.600s', 'startTime': '69.500s', 'word': '辦'},
#     {'endTime': '69.800s', 'startTime': '69.600s', 'word': '人'},
#     {'endTime': '70.100s', 'startTime': '69.800s', 'word': '的'},
#     {'endTime': '70.800s', 'startTime': '70.100s', 'word': '職'},
#     {'endTime': '71.100s', 'startTime': '70.800s', 'word': '權'},
#     {'endTime': '71.400s', 'startTime': '71.100s', 'word': '保'},
#     {'endTime': '72.500s', 'startTime': '71.400s', 'word': '證'},
#     {'endTime': '72.800s', 'startTime': '72.500s', 'word': '各'},
#     {'endTime': '73.100s', 'startTime': '72.800s', 'word': '做'},
#     {'endTime': '73.200s', 'startTime': '73.100s', 'word': '一'},
#     {'endTime': '73.400s', 'startTime': '73.200s', 'word': '個'},
#     {'endTime': '73.700s', 'startTime': '73.400s', 'word': '檢'},
#     {'endTime': '73.800s', 'startTime': '73.700s', 'word': '討'},
#     {'endTime': '74.100s', 'startTime': '73.800s', 'word': '更'},
#     {'endTime': '74.300s', 'startTime': '74.100s', 'word': '改'},
#     {'endTime': '74.600s', 'startTime': '74.300s', 'word': '進'},
#     {'endTime': '75.100s', 'startTime': '74.600s', 'word': '這'},
#     {'endTime': '75.200s', 'startTime': '75.100s', 'word': '個'}]}],
#  'languageCode': 'cmn-hant-tw',
#  'resultEndTime': '75.420s'}

# %% [markdown]
# ## 兩邊對齊

# %%
from difflib import SequenceMatcher
from tqdm.auto import tqdm
import numpy as np
win = 20
offset = 2
asr_words = flat_asr["words"]
asr_starts = flat_asr["starts"]
is_punct = lambda x: x in "，。：）（"

aligned_turn_start = []
for turn_x in tqdm(turns):
    probe = turn_x[1][offset:offset+win]    

    scores = []
    for i in range(len(asr_words)-win):                
        target = "".join(asr_words[i:i+win])
        sm = SequenceMatcher(is_punct,
                probe, target)
        scores.append(sm.ratio())

    align_idx = np.argmax(scores)
    print(f"[{max(scores)}]")
    print("Probe:", probe)
    print("Target: ", "".join(asr_words[align_idx:align_idx+20]))
    aligned_turn_start.append(asr_starts[align_idx])
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# [0.3]
# Probe: 0 時 13 分）部長，您好。遊艇證照弊
# Target:  人不算機業局長有沒有局長不長你好遊艇證照
# [0.35714285714285715]
# Probe: 通部林部長說明。
# Target:  啊除了重大的漏洞這個部分來請部長簡單說明
# [0.8]
# Probe: 原因是什麼，我們要阻止類似的事情再發生，
# Target:  原因是什麼然後我們要阻止這個類似的事情再
# [0.8]
# Probe: 局的檢討報告提到，要限縮相關人員的權限，
# Target:  局相關的檢討報告提到要先說相關人員的權限
# [0.3225806451612903]
# Probe: 通部航港局葉局長說明。
# Target:  重大的一個影響那這個部分來警局長簡單說明
# [0.65]
# Probe: 委員，目前我們已經全面變更並改正系統的設
# Target:  目前我們已經全面的這個變更這個改正這個系
# [0.65]
# Probe: 這個部分，剛才很多委員提到相關的題庫艱深
# Target:  查核好這個部分啊我們剛才很多也提到相關的
# [0.6]
# Probe: 員報告，全球海運缺櫃的現象是受到新冠肺炎
# Target:  部分全球的海運衰退現像是受到這個新冠肺炎
# [0.7]
# Probe: ，我們針對缺櫃這樣一個嚴重的狀況，有沒有
# Target:  是局長我們針對缺櫃的嚴重的狀況我們有沒有
# [0.65]
# Probe: 員報告，去年 10 月部長就提醒我們有這
# Target:  跟我們報告去年這個時樂部長就提醒我們有這
# [0.6]
# Probe: ，這個非常重要，因為我們在 1 月的時候
# Target:  不然這個非常重要因為我們在醫院收看整體的
# [0.65]
# Probe: 現在大概不缺櫃而是價格的問題，至於供需，
# Target:  數量的狀況又現在大概不缺櫃還是價格的問題
# [0.7]
# Probe: 必須要清楚掌握這些艙位以及貨櫃數量，因為
# Target:  必需要清楚地掌握著香味以及貨櫃的數量因為
# [0.0]
# Probe:
# Target:  謝謝主席請夏林佳龍部長還很有錢人家人不算
# [0.65]
# Probe: 我要請教葉局長，有關於郵輪觀光的發展，不
# Target:  在我請假謝其長在有關於郵輪觀光的一個發展
# [0.9]
# Probe: 員報告，這個部分的確跟原來預估有一個落差
# Target:  印報告這個部分的確跟原來預估了有一個落差
# [0.7]
# Probe: 、局長，航港局必須跟港務公司、業者、地方
# Target:  根局長我們必須航港局要跟港務公司業者地方
# [0.7]
# Probe: 委員說明，其實為什麼 1 月那時候會降下
# Target:  委員說明其實為什麼娛樂那個時候會有有有降
# [0.3076923076923077]
# Probe: 分可以理解。
# Target:  一些群聚的把感染症是非常嚴重者還可以理解
# [0.65]
# Probe: 疫苗也研發了，再考量各方的情況，所以我們
# Target:  解那現在我想疫苗研發到各方的情況所以我們
# [0.1935483870967742]
# Probe: 長全力督促，繼續加油！
# Target:  多少錢高雄港的問我們為條件項權利權力加油
# [0.25]
# Probe: 一定會全力來辦理，謝謝。
# Target:  部的工業局國貿局一定農會還有這個總公司來

# %%
from datetime import timedelta
for start_time, (speaker, transcript) in zip(aligned_turn_start, turns):
    timestamp = str(timedelta(seconds=start_time)).split(".")[0]
    print("[{}] {} {}".format(timestamp, speaker, transcript))
# Out:
# [0:00:09] 李委員昆澤： （10 時 13 分）部長，您好。遊艇證照弊案傷害政府的威信，也影響到考照的公平性，更是衝擊到航運的安全，這一次的事件整體來看，內部監理出了重大漏洞，這個部分請部長簡單說明一下。
# [0:00:34] 主席： 請交通部林部長說明。
# [0:00:42] 林部長佳龍： 不管原因是什麼，我們要阻止類似的事情再發生，所以我在第一時間得知檢調在偵辦，就要求同仁同步清查並全面提供資料，而且要澈底建立防弊的措施，不管是相關的作業程序或者承辦人的職權，整個檢討跟改進。
# [0:01:19] 李委員昆澤： 航港局的檢討報告提到，要限縮相關人員的權限，加強勾稽比對，並由科長來核對、覆核，系統要更新，限制成績須整批匯入，發照人員也要定期輪調。我也具體的建議，我們必須要加強內部稽核和不定期查核，請簡單說明。
# [0:03:48] 主席： 請交通部航港局葉局長說明。
# [0:01:43] 葉局長協隆： 謝謝委員，目前我們已經全面變更並改正系統的設定，還有受理申辦的流程，現在承辦人是沒有辦法做任何資料的更改，在發證前，系統也設定成績必須要合格才能夠發證，在考駕照的控管上，也由科長來控管空白駕照以及流水號，每天都必須要逐日核對，並按月做成紀錄往上呈報並做覆核。另外委員剛剛提醒的，要做實地和外部的稽核部分，我們去年 10 月和去年 12 月已經做了兩次到中部航務中心的外部稽核，今年 6 月和 7 月也分別會針對六大項目來進行進一步的實地查核。
# [0:02:40] 李委員昆澤： 好，這個部分，剛才很多委員提到相關的題庫艱深，而且大部分都是船機的相關知識，我們應該強化考照的流程，另外針對題庫的合理性以及相關的適用性，必須提出更具體的檢討和改進，而且航行的安全教育真的是非常重要，也必須要加強。我現在要請教的是針對貨櫃的數量，航港局有沒有掌握？現在因為疫情的影響，全世界的海運快速發展，大家需求的貨櫃數量都大幅增加，甚至有錢可能也買不到貨櫃，相關的狀況，我們看到臺灣是一個重要的進出口國家，海運是我們重要的經濟支柱，相對的，海運如果缺乏貨櫃的話，恐怕對經濟會造成重大的影響，這部分請局長簡單說明一下。
# [0:03:56] 葉局長協隆： 跟委員報告，全球海運缺櫃的現象是受到新冠肺炎疫情的影響，造成港口塞港以致貨櫃的回流速度減緩，造成整個缺櫃的情形。
# [0:04:11] 李委員昆澤： 局長，我們針對缺櫃這樣一個嚴重的狀況，有沒有具體的改善重點？甚至我們有沒有成立協調的工作小組去盤點相關的廠商出口的需求？對於空櫃的回流是不是有具體的掌握？請具體說明。
# [0:04:34] 葉局長協隆： 跟委員報告，去年 10 月部長就提醒我們有這樣的現象，我們經過檢討之後，在去年12 月已經成立一個國際海運的平穩小組，除了航港局之外，並由經濟部工業局、國貿局及農委會、港務公司來組成，我們採取的措施總共有五大部分，第一個就是剛剛委員提到的，我們每10 天到兩個禮拜主動調查進出口業者貨櫃的需求，如果有無法滿足的部分，我們會主動協調國籍航商來提供增加船班和艙位以滿足需求。我用幾個數字跟委員很快報告一下，第一，我們在 1 月初調查第一次的時候，需要的家數有97 家有貨櫃無法滿足的情形，數量是 1 萬 5,000 個，在經過第二次這樣的協調機制之後，在 1月底已經降到 32 家 230 個貨櫃；到 2 月底的時候，只剩下 9 家有貨櫃無法滿足的情形，需求的貨櫃是 53 個；到 3 月底的數字是 30 家 79 個貨櫃無法滿足，整個貨櫃的提供率大概是八成左右，如果沒有辦法滿足 100 個貨櫃，我們透過協調能夠提供 80 個貨櫃，另外還有 20 個貨櫃沒有辦法滿足的部分，最主要是買方和賣方因為運價的考量暫時沒有辦法達成協議，針對這個部分，我們也建議雙方在現有商業協調機制，可以透過運費的協議，讓貨櫃的出口更順暢。
# [0:06:36] 李委員昆澤： 部長，這個非常重要，因為我們在 1 月的時候整體的出口增加 30%以上，尤其在第三季更是進出口一個重要的旺季，相關的貨櫃數量也影響到我們臺灣整體出口的產業經濟發展，部長有沒有掌握相關貨櫃數量的狀況？
# [0:07:00] 林部長佳龍： 有，現在大概不缺櫃而是價格的問題，至於供需，我主持過會議，我們召集 4 家國籍航商及業者、公協會坐下來談，所以除了一個資訊平臺，大概把過年前塞櫃問題解決得差不多，將近有兩萬 TEU，現在針對今年可能的缺櫃，我們也超前部署，一家一家調查，目前總共有46 艘新船會進來，大概有 33 萬 TEU 可以來提供我們的國貨由國人來運。當然，在商言商，過去我們的國籍航商也不一定優先以國內的需求為主，導致價格惡性競爭，事實上是虧損，所以這個時候我們利用這個危機希望建立一個平臺，在符合公平交易和世界貿易組織的規範下，我們當然可以鼓勵簽一些長約，讓國內這些很重要的產業有國籍航商可以先運；另外一點，對於外籍航商能夠靠港，我們也提供一些優惠，所以到目前來講，今年度開始，雖然貨櫃的價格還是高，但是供需大概是可以滿足國內產業的需求。
# [0:08:24] 李委員昆澤： 部長必須要清楚掌握這些艙位以及貨櫃數量，因為這的確是影響臺灣的海運以及整體出口的相關產業經濟之整體發展，而且剛才我也提醒你，第三季旺季馬上就要到了。
# [0:00:01] 林部長佳龍： 對。
# [0:08:40] 李委員昆澤： 現在我要請教葉局長，有關於郵輪觀光的發展，不管是跳島或是環島，郵輪在高雄的發展成效都必須要加強，因為我在 2020 年 12 月 28 日質詢時，航港局表示 2020 年 12 月 27 日到 2021 年 4 月 5 日，跳島和環島航程預計有 42 航次，而且航港局已經安排 21 航次停靠高雄港，加上該等航次中，會有 6 個航次是由高雄港出發，聽起來很開心，但是實際上到 2021 年 3 月11 日為止，總共是 46 航次，其中 21 個航次是去年 12 月 28 日之前，而且實際航次只有 25 個航次而已，所以 2020 年 12 月到 2021 年 4 月總共有 8 個航次停靠高雄港而已，但是原始預估到 4月 5 日應該要到達 21 個航次，「說的嚇死人、做的笑死人」，差很多耶！局長的宣示跟實際上的效果差很多，你來說明一下。
# [0:10:06] 葉局長協隆： 跟委員報告，這個部分的確跟原來預估有一個落差，我們瞭解最主要是年初的時候受到海氣象影響，還有載客率和訂位的情況不甚理想等原因，有取消部分的航班，這個部分我們會主動來協調郵輪業者跟港務公司，透過這些優惠的措施來鼓勵業者停靠高雄，目前有相關新的郵輪業者來跟我們接洽，這個部分我們都會鼓勵高雄這邊，不管是母港或掛靠港，多從高雄這邊來出發。
# [0:10:46] 李委員昆澤： 部長、局長，航港局必須跟港務公司、業者、地方政府密切合作，你要提供優質有特色的相關服務，而且針對相關停靠的費用，我們是否給予優待跟減免以吸引更多業者到高雄？這個部分說明一下。
# [0:11:10] 林部長佳龍： 我跟委員說明，其實為什麼 1 月那時候會降下來，除了剛剛局長講的，還有疫情，那一陣子因為部桃的關係，所以我們事實上是很謹慎，因為郵輪可能萬一有一些群聚的感染，這是非常嚴重的。所以寧可……
# [0:11:27] 李委員昆澤： 這部分可以理解。
# [0:11:32] 林部長佳龍： 現在疫苗也研發了，再考量各方的情況，所以我們也啟動新一輪遊輪跳島的許可。現在全世界很多的郵輪業都想申請來臺灣，我們很謹慎，現在有 3 大 1 小在申請中。高雄港的部分，我們認為條件非常好。
# [0:11:52] 李委員昆澤： 請部長全力督促，繼續加油！
# [0:04:49] 林部長佳龍： 我們一定會全力來辦理，謝謝。
